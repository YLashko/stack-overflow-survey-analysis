# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("survey_results_public.csv")
data.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
cols_to_keep = ['MainBranch', 'Employment', 'RemoteWork', 'YearsCode', 'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith']

# %%
data = data[cols_to_keep]

# %%
data = data[~data["MainBranch"].isin(["None of these", "I used to be a developer by profession, but no longer am"])] # remove non-developers

# %%
data["YearsCode"].value_counts()
# Out:
# 10                    5162
# 5                     5143
# 6                     4614
# 4                     4449
# 7                     4202
# 8                     4198
# 3                     4084
# 2                     3322
# 12                    2951
# 15                    2883
# 20                    2568
# 9                     2562
# 11                    1793
# 14                    1784
# 13                    1604
# 1                     1559
# 25                    1535
# Less than 1 year      1399
# 16                    1383
# 30                    1264
# 22                    1138
# 18                    1125
# 17                    1042
# 40                     719
# 24                     717
# 35                     708
# 23                     630
# 19                     547
# 21                     476
# 26                     475
# 27                     468
# 28                     408
# 32                     353
# 38                     275
# 37                     267
# 34                     233
# 36                     225
# 33                     221
# 42                     202
# 29                     201
# 31                     164
# 45                     154
# 39                     152
# More than 50 years     144
# 41                     135
# 43                     107
# 44                      93
# 50                      59
# 46                      50
# 47                      37
# 48                      33
# 49                      30
# Name: YearsCode, dtype: int64

# %%
# transform years to code
transformation_dict = {
    "Less than 1 year": 0.0,
    "More than 50 years": 51
}

def years_code_to_float(data):
    try:
        return float(data)
    except:
        return transformation_dict[data]

# %%
data["YearsCode"] = data["YearsCode"].apply(years_code_to_float) # convert YearsCode to float

# %%
data
# Out:
#                                               MainBranch  \
# 1                         I am a developer by profession
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 4                         I am a developer by profession
# 5      I am not primarily a developer, but I write co...
# ...                                                  ...
# 73262                              I am learning to code
# 73263                     I am a developer by profession
# 73264                     I am a developer by profession
# 73265  I am not primarily a developer, but I write co...
# 73266                     I am a developer by profession
#
#                                    Employment  \
# 1                         Employed, full-time
# 2                         Employed, full-time
# 3                         Employed, full-time
# 4                         Employed, full-time
# 5                          Student, full-time
# ...                                       ...
# 73262  Student, full-time;Employed, part-time
# 73263                     Employed, full-time
# 73264                     Employed, full-time
# 73265                     Employed, full-time
# 73266                     Employed, full-time
#
#                                  RemoteWork  YearsCode  CompTotal CompFreq  \
# 1                              Fully remote        NaN        NaN      NaN
# 2      Hybrid (some remote, some in-person)       14.0    32000.0   Yearly
# 3                              Fully remote       20.0    60000.0  Monthly
# 4      Hybrid (some remote, some in-person)        8.0        NaN      NaN
# 5                                       NaN       15.0        NaN      NaN
# ...                                     ...        ...        ...      ...
# 73262  Hybrid (some remote, some in-person)        4.0        NaN      NaN
# 73263                          Fully remote        8.0    60000.0   Yearly
# 73264                        Full in-person        6.0   107000.0   Yearly
# 73265  Hybrid (some remote, some in-person)       42.0        NaN      NaN
# 73266  Hybrid (some remote, some in-person)       50.0    58500.0   Yearly
#
#                                   LanguageHaveWorkedWith
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# 5                                                C++;Lua
# ...                                                  ...
# 73262                     Assembly;C;C++;Java;TypeScript
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
#
# [70475 rows x 7 columns]

# %%
data = data[data["CompTotal"] < 1e+7] # remove rows with too large salary

# %%
data[data["CompFreq"] == "Monthly"].describe() # there is a problem with montly computed data, some people still provide yearly salary
# Out:
#           YearsCode     CompTotal
# count  14380.000000  1.441000e+04
# mean      12.368289  1.963028e+05
# std        8.535292  8.047991e+05
# min        0.000000  0.000000e+00
# 25%        6.000000  4.350000e+03
# 50%       10.000000  1.765600e+04
# 75%       16.000000  6.800000e+04
# max       51.000000  9.700000e+06

# %%
languages = data["LanguageHaveWorkedWith"]

# %%
def apply_split(row):
    try:
        return row.split(";")
    except:
        return [row]

# %%
languages = languages.apply(apply_split)

# %%
unique = np.unique(np.concatenate(languages.values)) # get all the unique languages

# %%
# create columns for each language and mark if user have worked with it

for unique_lang in unique:
    data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)

for unique_lang in unique:
    data[unique_lang] = data[unique_lang].apply(lambda r: unique_lang in r)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data["LanguageHaveWorkedWith"].apply(apply_split)
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\497855325.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[unique_lang] = data[unique_lang].apply(lambda r: unique_lang in r)

# %%
data
# Out:
#                                               MainBranch  \
# 2      I am not primarily a developer, but I write co...
# 3                         I am a developer by profession
# 8                         I am a developer by profession
# 10                        I am a developer by profession
# 11     I am not primarily a developer, but I write co...
# ...                                                  ...
# 73259                     I am a developer by profession
# 73261                     I am a developer by profession
# 73263                     I am a developer by profession
# 73264                     I am a developer by profession
# 73266                     I am a developer by profession
#
#                                               Employment  \
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 8                                    Employed, full-time
# 10                                   Employed, full-time
# 11     Employed, full-time;Independent contractor, fr...
# ...                                                  ...
# 73259                                Employed, full-time
# 73261                                Employed, full-time
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73266                                Employed, full-time
#
#                                  RemoteWork  YearsCode  CompTotal CompFreq  \
# 2      Hybrid (some remote, some in-person)       14.0    32000.0   Yearly
# 3                              Fully remote       20.0    60000.0  Monthly
# 8      Hybrid (some remote, some in-person)        6.0    46000.0   Yearly
# 10     Hybrid (some remote, some in-person)        5.0    48000.0   Yearly
# 11                             Fully remote       12.0   194400.0   Yearly
# ...                                     ...        ...        ...      ...
# 73259  Hybrid (some remote, some in-person)        6.0     8000.0  Monthly
# 73261  Hybrid (some remote, some in-person)        9.0    36000.0   Yearly
# 73263                          Fully remote        8.0    60000.0   Yearly
# 73264                        Full in-person        6.0   107000.0   Yearly
# 73266  Hybrid (some remote, some in-person)       50.0    58500.0   Yearly
#
#                                   LanguageHaveWorkedWith    APL  Assembly  \
# 2                      C#;C++;HTML/CSS;JavaScript;Python  False     False
# 3                           C#;JavaScript;SQL;TypeScript  False     False
# 8                                                    NaN  False     False
# 10      Bash/Shell;C#;HTML/CSS;JavaScript;PowerShell;SQL  False     False
# 11     C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL  False     False
# ...                                                  ...    ...       ...
# 73259                                             Elixir  False     False
# 73261  Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...  False     False
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...  False     False
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL  False     False
# 73266                                      C#;Delphi;VBA  False     False
#
#        Bash/Shell  ...   Ruby   Rust    SAS    SQL  Scala  Solidity  Swift  \
# 2           False  ...  False  False  False  False  False     False  False
# 3           False  ...  False  False  False   True  False     False  False
# 8           False  ...  False  False  False  False  False     False  False
# 10           True  ...  False  False  False   True  False     False  False
# 11          False  ...  False   True  False   True  False     False  False
# ...           ...  ...    ...    ...    ...    ...    ...       ...    ...
# 73259       False  ...  False  False  False  False  False     False  False
# 73261        True  ...  False  False  False   True  False     False  False
# 73263        True  ...  False  False  False   True  False     False  False
# 73264        True  ...  False  False  False   True  False     False  False
# 73266       False  ...  False  False  False  False  False     False  False
#
#        TypeScript    VBA    nan
# 2           False  False  False
# 3            True  False  False
# 8           False  False  False
# 10          False  False  False
# 11          False  False  False
# ...           ...    ...    ...
# 73259       False  False  False
# 73261        True  False  False
# 73263        True  False  False
# 73264       False  False  False
# 73266       False   True  False
#
# [37741 rows x 50 columns]

# %%
data.drop(columns=["LanguageHaveWorkedWith", "nan"], inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7152\964770955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=["LanguageHaveWorkedWith", "nan"], inplace=True)

# %%
data.to_csv("survey_results_prepared.csv")
